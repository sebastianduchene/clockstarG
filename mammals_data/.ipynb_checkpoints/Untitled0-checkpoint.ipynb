# %%
import os
import sys
import re
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir("empirical_data/")

# %%
os.listdir(os.getcwd())
# Out:
# ['eig_mds.txt',
#  'no_eq.tree',
#  'out1.trees',
#  'out_boot1.txt',
#  'out_clus_sil.txt',
#  'points_mds.txt',
#  'sbsd.txt',
#  'sbsdout.fold.txt',
#  'sout.fold.txt']

# %%
dat_points = pd.read_csv("points_mds.txt", sep = " ")

# %%
dat_points.head()
# Out:
#                      V1        V2        V3
# gene1.fasta    0.052867 -0.583291  0.405947
# gene10.fasta   0.727453  0.621395 -0.333493
# gene100.fasta -0.221254  0.562886  0.199727
# gene101.fasta -0.264150  0.300100  0.445060
# gene102.fasta  1.326084  0.192905 -0.380770
#
# [5 rows x 3 columns]

# %%
plt.plot(dat_points.ix[range(10),0], dat_points.ix[range(10), 1], 'o')
plt.plot(dat_points.ix[range(11, 30), 0], dat_points.ix[range(11, 30, 1)], 'ro')

# %%
shape(dat_points)
# Out:
# (431, 3)

# %%
clus_data = open('../cluster_gene_info.txt', 'r').readlines()

# %%
lens_dat = [len(re.split(r'@|,', clus_data[i])) for i in range(len(clus_data))]

# %%
plt.hist(lens_dat)
# Out:
# (array([ 310.,   86.,   19.,   12.,    1.,    1.,    1.,    0.,    0.,    1.]),
#  array([  9. ,  11.6,  14.2,  16.8,  19.4,  22. ,  24.6,  27.2,  29.8,
#          32.4,  35. ]),
#  <a list of 10 Patch objects>)

# %%
for i in range(len(clus_data)):
    print re.split(r'@|,', clus_data[i])[8]
# Out:
# NA
#
# AP-1-dependent up-regulation of the P2 promoter
# cd02537: GT8_Glycogenin; Glycogenin belongs the GT 8 family and initiates the biosynthesis of glycogen
#
# cl10469: Transglut_core; Transglutaminase-like superfamily
#
# NA
#
# chromosome 1 alternate HuRef
# chromosome 20 alternate HuRef
# cd00116: LRR_RI; Leucine-rich repeats (LRRs)
# This gene encodes a member of the oxysterol-binding protein (OSBP) family
#  liver
# chromosome 15 alternate HuRef
# NA
#
# ...

# %%
re.split(r'@|,', clus_data[1])
# Out:
# ['CLUSTER1',
#  'gene107',
#  '1390',
#  '<Entrezgene_type value="protein-coding">6',
#  'Homo sapiens',
#  'CREM',
#  'cAMP responsive element modulator',
#  'chromosome 10 alternate HuRef',
#  'AP-1-dependent up-regulation of the P2 promoter',
#  ' SLE T cells fail to further increase their basal CREM levels upon T cell activation due to a decreased content of the AP-1 family member c-Fos\n']

# %%
dir(array([3, 4, 5]))
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_wrap__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__delslice__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__hex__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...
